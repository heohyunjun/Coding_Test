# %% [markdown]
# # 해시

# %% [markdown]
# - particiant : 마라톤에 참여한 선수들의 이름이 담긴 배열
# - completion : 완주한 선수들의 이름이 담긴 배열
# - 완주하지 못한 선수의 이름을 return

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
participant = ["marina", "josipa", "nikola", "vinko", "filipa", "vinko"]
completion =["josipa", "filipa", "marina", "nikola"]

# %%
def solution(participant, completion): 
  hash ={} 
  for i in participant: 
    if i in hash: 
      hash[i] += 1 
    else: 
      hash[i] = 1 

  for i in completion: 
    if hash[i] == 1: 
      del hash[i] 
    else: 
      hash[i] -= 1 
  answer = list(hash.keys())[0] 
  return answer

# %%
import collections
def solution(participant, completion):
    print(collections.Counter(participant))
    print(collections.Counter(completion))
    answer = collections.Counter(participant) - collections.Counter(completion)
    return list(answer.keys())[0]

# %%
solution(participant, completion)
# Out:
# Counter({'vinko': 2, 'filipa': 1, 'josipa': 1, 'marina': 1, 'nikola': 1})
# Counter({'filipa': 1, 'josipa': 1, 'marina': 1, 'nikola': 1})
# 'vinko'
